# %%
import pandas as pd
import folium
from folium.plugins import MarkerCluster
from folium.plugins import HeatMap
import io
from PIL import Image

# %%
df_furtos = pd.read_csv('D:\\EPS\\TCC\\data_cleaned\\SSP\\furtos_2018.csv', sep=",", decimal=".")
# Out:
# D:\Programas\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_furtos.head()
# Out:
#    ANO_BO  NUM_BO NUMERO_BOLETIM          BO_INICIADO           BO_EMITIDO  \
# 0    2018     111       111/2018  01/01/2018 04:10:03  01/01/2018 04:10:03
# 1    2018    1772      1772/2018  02/05/2018 17:28:51  02/05/2018 17:37:29
# 2    2018  574601    574601/2018  02/05/2018 17:36:20  02/05/2018 17:36:20
# 3    2018  574785    574785/2018  02/05/2018 17:25:57  02/05/2018 17:25:57
# 4    2018  574911    574911/2018  02/05/2018 17:24:45  02/05/2018 17:24:45
#
#   DATAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO       DATAELABORACAO  \
# 0     2018-01-01     DE MADRUGADA      01/01/2018  01/01/2018 04:10:03
# 1     2018-02-05          A TARDE      02/05/2018  02/05/2018 17:28:51
# 2     2018-02-05       PELA MANHÃ      02/05/2018  02/05/2018 17:36:20
# 3     2018-02-05       PELA MANHÃ      02/05/2018  02/05/2018 17:25:57
# 4     2018-02-05       PELA MANHÃ      02/05/2018  02/05/2018 17:24:45
#
#      BO_AUTORIA  ... IDADE PLACA_VEICULO UF_VEICULO  CIDADE_VEICULO  \
# 0  Desconhecida  ...   NaN       FAG1865         SP         S.PAULO
# 1  Desconhecida  ...   NaN       FDQ7766         SP         S.PAULO
# 2  Desconhecida  ...   NaN       CDI3914         SP         S.PAULO
# 3  Desconhecida  ...   NaN           NaN        NaN             NaN
# 4  Desconhecida  ...   NaN       EMS7306         SP         S.PAULO
#
#   DESCR_COR_VEICULO       DESCR_MARCA_VEICULO ANO_FABRICACAO ANO_MODELO  \
# 0             Preta      I/FIAT SIENA EL FLEX         2011.0     2011.0
# 1             Cinza        HONDA/HR-V EXL CVT         2016.0     2016.0
# 2              Azul     HONDA/CG 150 TITAN KS         2008.0     2008.0
# 3               NaN                       NaN            NaN        NaN
# 4             Preta  I/KIA SPORTAGE EX2 2.0G2         2010.0     2010.0
#
#   DESCR_TIPO_VEICULO DIASEMANA
# 0          AUTOMOVEL         0
# 1          AUTOMOVEL         0
# 2          MOTOCICLO         0
# 3                NaN         0
# 4          AUTOMOVEL         0
#
# [5 rows x 39 columns]

# %%
df_furtos.dropna(subset=['BAIRRO'], inplace=True)
df_furtos.dropna(subset=['CIDADE'], inplace=True)

# %%
df_furtos['LONGITUDE'] = df_furtos['LONGITUDE'].str.replace(',', '.').astype(float)
df_furtos.dropna(subset=['LONGITUDE'], inplace=True)
df_furtos['LATITUDE'] = df_furtos['LATITUDE'].str.replace(',', '.').astype(float)
df_furtos.dropna(subset=['LATITUDE'], inplace=True)

# %%
# Inicializamos o mapa com as coordenadas centrais da Avenida Paulista
mapa = folium.Map(location=[-23.5631, -46.6543], control_scale=True, zoom_start=16)

# Passamos as latitudes e longitudes para listas para poder adicionar ao mapa
lat = df_furtos['LATITUDE'].tolist()
lng = df_furtos['LONGITUDE'].tolist()
lista = list(zip(lat, lng))

# Adicionamos a lista ao mapa e salvamos no formato PNG
HeatMap(lista).add_to(mapa)

img_data = mapa._to_png(5)
img = Image.open(io.BytesIO(img_data))
img.save('Heat_Paulista_Furtos_2018.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# D:\Programas\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      71             cmd.extend(self.command_line_args())
# ---> 72             self.process = subprocess.Popen(cmd, env=self.env,
#      73                                             close_fds=platform.system() != 'Windows',
#
# D:\Programas\Anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     853
# --> 854             self._execute_child(args, executable, preexec_fn, close_fds,
#     855                                 pass_fds, cwd, env,
#
# D:\Programas\Anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1306             try:
# -> 1307                 hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1308                                          # no special security
#
# FileNotFoundError: [WinError 2] O sistema não pode encontrar o arquivo especificado
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-21-268b89b614b8> in <module>
#      10 HeatMap(lista).add_to(mapa)
#      11
# ---> 12 img_data = mapa._to_png(5)
#      13 img = Image.open(io.BytesIO(img_data))
#      14 img.save('Heat_Paulista_Furtos_2018.png')
#
# D:\Programas\Anaconda3\lib\site-packages\folium\folium.py in _to_png(self, delay)
#     311             options = webdriver.firefox.options.Options()
#     312             options.add_argument('--headless')
# --> 313             driver = webdriver.Firefox(options=options)
#     314
#     315             html = self.get_root().render()
#
# D:\Programas\Anaconda3\lib\site-packages\selenium\webdriver\firefox\webdriver.py in __init__(self, firefox_profile, firefox_binary, timeout, capabilities, proxy, executable_path, options, service_log_path, firefox_options, service_args, desired_capabilities, log_path, keep_alive)
#     162                 service_args=service_args,
#     163                 log_path=service_log_path)
# --> 164             self.service.start()
#     165
#     166             capabilities.update(options.to_capabilities())
#
# D:\Programas\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      79         except OSError as err:
#      80             if err.errno == errno.ENOENT:
# ---> 81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
#      83                         os.path.basename(self.path), self.start_error_message)
#
# WebDriverException: Message: 'geckodriver' executable needs to be in PATH.

# %%
# Inicializamos o mapa com as coordenadas centrais da cidade de São Paulo
mapa = folium.Map(location=[-23.5475, -46.63611], control_scale=True)

# Passamos as latitudes e longitudes para listas para poder adicionar ao mapa
lat = df_furtos['LATITUDE'].tolist()
lng = df_furtos['LONGITUDE'].tolist()
lista = list(zip(lat, lng))

# Adicionamos a lista ao mapa e salvamos no formato de HTML
HeatMap(lista).add_to(mapa)
mapa.save('Heat_SP_Furtos_2018.html')

# Aqui recriamos o mapa, mas agora com marcadores
mapa = folium.Map(location=[-23.5475, -46.63611], control_scale=True)
mc = MarkerCluster()

# Contamos cada par de latitude e longitude e adicionamos a um marcador e salvamos o mapa como HTML
for val in lista:
    mc.add_child(folium.Marker([val[0], val[1]], icon=folium.Icon(icon='book'))).add_to(mapa)
mapa.save('Marker_SP_Furtos_2018.html')

# %%
df_roubos = pd.read_csv('D:\\EPS\\TCC\\data_cleaned\\SSP\\roubos_2018.csv', sep=",", decimal=".")

# %%
df_roubos.dropna(subset=['BAIRRO'], inplace=True)
df_roubos.dropna(subset=['CIDADE'], inplace=True)

# %%
df_roubos['LONGITUDE'] = df_roubos['LONGITUDE'].str.replace(',', '.').astype(float)
df_roubos.dropna(subset=['LONGITUDE'], inplace=True)
df_roubos['LATITUDE'] = df_roubos['LATITUDE'].str.replace(',', '.').astype(float)
df_roubos.dropna(subset=['LATITUDE'], inplace=True)

# %%
# Inicializamos o mapa com as coordenadas centrais da cidade de São Paulo
mapa = folium.Map(location=[-23.5475, -46.63611], control_scale=True)

# Passamos as latitudes e longitudes para listas para poder adicionar ao mapa
lat = df_roubos['LATITUDE'].tolist()
lng = df_roubos['LONGITUDE'].tolist()
lista = list(zip(lat, lng))

# Adicionamos a lista ao mapa e salvamos no formato de HTML
HeatMap(lista).add_to(mapa)
mapa.save('Heat_SP_Roubos_2018.html')

# Aqui recriamos o mapa, mas agora com marcadores
mapa = folium.Map(location=[-23.5475, -46.63611], control_scale=True)
mc = MarkerCluster()

# Contamos cada par de latitude e longitude e adicionamos a um marcador e salvamos o mapa como HTML
for val in lista:
    mc.add_child(folium.Marker([val[0], val[1]], icon=folium.Icon(icon='book'))).add_to(mapa)
mapa.save('Marker_SP_Roubos_2018.html')
