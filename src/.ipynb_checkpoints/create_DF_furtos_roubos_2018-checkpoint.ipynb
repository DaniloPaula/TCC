# %%
import pandas as pd
import datetime as dt

# %% [markdown]
# ## Criação da base de 2018 para furtos

# %%
# Criação da base de 2018 para furtos
df_furtos = pd.read_csv('D:\\EPS\\TCC\\data_cleaned\\SSP\\furtosConcat.csv', sep=",", decimal=".")
# Out:
# D:\Programas\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (17,18,28,30,31,32,33,34,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_furtos.columns
# Out:
# Index(['ANO_BO', 'NUM_BO', 'NUMERO_BOLETIM', 'BO_INICIADO', 'BO_EMITIDO',
#        'DATAOCORRENCIA', 'PERIDOOCORRENCIA', 'DATACOMUNICACAO',
#        'DATAELABORACAO', 'BO_AUTORIA', 'FLAGRANTE', 'NUMERO_BOLETIM_PRINCIPAL',
#        'LOGRADOURO', 'NUMERO', 'BAIRRO', 'CIDADE', 'UF', 'LATITUDE',
#        'LONGITUDE', 'DESCRICAOLOCAL', 'EXAME', 'SOLUCAO', 'DELEGACIA_NOME',
#        'DELEGACIA_CIRCUNSCRICAO', 'ESPECIE', 'RUBRICA', 'DESDOBRAMENTO',
#        'STATUS', 'SEXO', 'IDADE', 'PLACA_VEICULO', 'UF_VEICULO',
#        'CIDADE_VEICULO', 'DESCR_COR_VEICULO', 'DESCR_MARCA_VEICULO',
#        'ANO_FABRICACAO', 'ANO_MODELO', 'DESCR_TIPO_VEICULO'],
#       dtype='object')

# %%
df_furtos.head()
# Out:
#    ANO_BO  NUM_BO NUMERO_BOLETIM          BO_INICIADO           BO_EMITIDO  \
# 0    2003      25        25/2003  01/01/2003 12:33:24  01/01/2003 12:36:16
# 1    2003       8         8/2003  01/01/2003 20:18:24  01/01/2003 20:46:57
# 2    2003      10        10/2003  02/01/2003 09:05:25  02/01/2003 09:05:27
# 3    2003      63        63/2003  02/01/2003 13:23:46  02/01/2003 13:28:49
# 4    2003      23        23/2003  02/01/2003 14:08:41  02/01/2003 14:08:45
#
#   DATAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO       DATAELABORACAO  \
# 0     01/01/2003     DE MADRUGADA      01/01/2003  01/01/2003 12:33:24
# 1     01/01/2002          A TARDE      01/01/2003  01/01/2003 20:18:24
# 2     31/12/2002          A NOITE      02/01/2003  02/01/2003 09:05:25
# 3     02/01/2003       PELA MANHÃ      02/01/2003  02/01/2003 13:23:46
# 4     31/12/2002          A TARDE      02/01/2003  02/01/2003 14:08:41
#
#      BO_AUTORIA  ... SEXO IDADE PLACA_VEICULO  UF_VEICULO CIDADE_VEICULO  \
# 0  Desconhecida  ...  NaN   NaN           NaN         NaN            NaN
# 1  Desconhecida  ...  NaN   NaN           NaN         NaN            NaN
# 2  Desconhecida  ...  NaN   NaN           NaN         NaN            NaN
# 3     Conhecida  ...  NaN   NaN           NaN         NaN            NaN
# 4  Desconhecida  ...  NaN   NaN           NaN         NaN            NaN
#
#   DESCR_COR_VEICULO DESCR_MARCA_VEICULO ANO_FABRICACAO ANO_MODELO  \
# 0               NaN                 NaN            NaN        NaN
# 1               NaN                 NaN            NaN        NaN
# 2               NaN                 NaN            NaN        NaN
# 3               NaN                 NaN            NaN        NaN
# 4               NaN                 NaN            0.0        0.0
#
#   DESCR_TIPO_VEICULO
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 38 columns]

# %%
# Convertemos para datetime
df_furtos['DATAOCORRENCIA'] = pd.to_datetime(df_furtos['DATAOCORRENCIA'], errors = 'coerce')

# %%
df_furtos.head()
# Out:
#    ANO_BO  NUM_BO NUMERO_BOLETIM          BO_INICIADO           BO_EMITIDO  \
# 0    2003      25        25/2003  01/01/2003 12:33:24  01/01/2003 12:36:16
# 1    2003       8         8/2003  01/01/2003 20:18:24  01/01/2003 20:46:57
# 2    2003      10        10/2003  02/01/2003 09:05:25  02/01/2003 09:05:27
# 3    2003      63        63/2003  02/01/2003 13:23:46  02/01/2003 13:28:49
# 4    2003      23        23/2003  02/01/2003 14:08:41  02/01/2003 14:08:45
#
#   DATAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO       DATAELABORACAO  \
# 0     2003-01-01     DE MADRUGADA      01/01/2003  01/01/2003 12:33:24
# 1     2002-01-01          A TARDE      01/01/2003  01/01/2003 20:18:24
# 2     2002-12-31          A NOITE      02/01/2003  02/01/2003 09:05:25
# 3     2003-02-01       PELA MANHÃ      02/01/2003  02/01/2003 13:23:46
# 4     2002-12-31          A TARDE      02/01/2003  02/01/2003 14:08:41
#
#      BO_AUTORIA  ... SEXO IDADE PLACA_VEICULO  UF_VEICULO CIDADE_VEICULO  \
# 0  Desconhecida  ...  NaN   NaN           NaN         NaN            NaN
# 1  Desconhecida  ...  NaN   NaN           NaN         NaN            NaN
# 2  Desconhecida  ...  NaN   NaN           NaN         NaN            NaN
# 3     Conhecida  ...  NaN   NaN           NaN         NaN            NaN
# 4  Desconhecida  ...  NaN   NaN           NaN         NaN            NaN
#
#   DESCR_COR_VEICULO DESCR_MARCA_VEICULO ANO_FABRICACAO ANO_MODELO  \
# 0               NaN                 NaN            NaN        NaN
# 1               NaN                 NaN            NaN        NaN
# 2               NaN                 NaN            NaN        NaN
# 3               NaN                 NaN            NaN        NaN
# 4               NaN                 NaN            0.0        0.0
#
#   DESCR_TIPO_VEICULO
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 38 columns]

# %%
# Filtramos os dados de 2018
furtos_2018 = df_furtos[df_furtos['DATAOCORRENCIA'].dt.year == 2018]

# %%
furtos_2018.head()
# Out:
#          ANO_BO  NUM_BO NUMERO_BOLETIM          BO_INICIADO  \
# 1696329    2018       7         7/2018  01/01/2018 00:48:34
# 1696333    2018       1         1/2018  01/01/2018 01:14:08
# 1696335    2018       1         1/2018  01/01/2018 01:19:53
# 1696336    2018       2         2/2018  01/01/2018 01:18:43
# 1696338    2018       1         1/2018  01/01/2018 01:33:40
#
#                   BO_EMITIDO DATAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO  \
# 1696329  01/01/2018 00:48:34     2018-01-01     DE MADRUGADA      01/01/2018
# 1696333  01/01/2018 01:20:23     2018-01-01     DE MADRUGADA      01/01/2018
# 1696335  01/01/2018 01:29:30     2018-01-01     DE MADRUGADA      01/01/2018
# 1696336  01/01/2018 01:32:36     2018-01-01     DE MADRUGADA      01/01/2018
# 1696338  01/01/2018 01:50:20     2018-01-01  EM HORA INCERTA      01/01/2018
#
#               DATAELABORACAO    BO_AUTORIA  ... SEXO IDADE PLACA_VEICULO  \
# 1696329  01/01/2018 00:48:34  Desconhecida  ...  NaN   NaN       CCX2566
# 1696333  01/01/2018 01:14:08  Desconhecida  ...  NaN   NaN       DFJ8925
# 1696335  01/01/2018 01:19:53  Desconhecida  ...  NaN   NaN       DOZ1584
# 1696336  01/01/2018 01:18:43  Desconhecida  ...  NaN   NaN       EHY2760
# 1696338  01/01/2018 01:33:40  Desconhecida  ...  NaN   NaN       CNX9337
#
#          UF_VEICULO CIDADE_VEICULO DESCR_COR_VEICULO    DESCR_MARCA_VEICULO  \
# 1696329          SP       LOUVEIRA             Preta         GM/KADETT SL/E
# 1696333          SP        JUNDIAI             Cinza       VW/GOL 16V POWER
# 1696335          SP     COSMOPOLIS             Preta  HONDA/CG 150 TITAN ES
# 1696336          SP     MOGI MIRIM             Prata   JTA/SUZUKI EN125 YES
# 1696338          SP      RIO CLARO            Branco   VW/SAVEIRO CL 1.6 MI
#
#         ANO_FABRICACAO ANO_MODELO DESCR_TIPO_VEICULO
# 1696329         1990.0     1990.0          AUTOMOVEL
# 1696333         2001.0     2002.0          AUTOMOVEL
# 1696335         2005.0     2006.0          MOTOCICLO
# 1696336         2008.0     2009.0          MOTOCICLO
# 1696338         1998.0     1998.0        CAMINHONETE
#
# [5 rows x 38 columns]

# %%
furtos_2018['CIDADE'] = furtos_2018['CIDADE'].str.upper()
# Out:
# D:\Programas\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# Dropamos outras cidades que nao são SP
furtos_2018.drop(furtos_2018[(furtos_2018.CIDADE != 'S.PAULO') & (furtos_2018.CIDADE != 'SAO PAULO') & (furtos_2018.CIDADE != 'SÃO PAULO') & (furtos_2018.CIDADE != 'SP')].index, inplace=True)
# Out:
# D:\Programas\Anaconda3\lib\site-packages\pandas\core\frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
furtos_2018['CIDADE'].unique()
# Out:
# array(['S.PAULO'], dtype=object)

# %%
furtos_2018['DIASEMANA'] = furtos_2018['DATAOCORRENCIA'].dt.dayofweek
# Out:
# D:\Programas\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
furtos_2018.sort_values('DIASEMANA', inplace=True)
# Out:
# D:\Programas\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
furtos_2018['DIASEMANA'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 6], dtype=int64)

# %%
furtos_2018.head()
# Out:
#          ANO_BO  NUM_BO NUMERO_BOLETIM          BO_INICIADO  \
# 1696362    2018     111       111/2018  01/01/2018 04:10:03
# 1777862    2018    1772      1772/2018  02/05/2018 17:28:51
# 1777857    2018  574601    574601/2018  02/05/2018 17:36:20
# 1777855    2018  574785    574785/2018  02/05/2018 17:25:57
# 1777854    2018  574911    574911/2018  02/05/2018 17:24:45
#
#                   BO_EMITIDO DATAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO  \
# 1696362  01/01/2018 04:10:03     2018-01-01     DE MADRUGADA      01/01/2018
# 1777862  02/05/2018 17:37:29     2018-02-05          A TARDE      02/05/2018
# 1777857  02/05/2018 17:36:20     2018-02-05       PELA MANHÃ      02/05/2018
# 1777855  02/05/2018 17:25:57     2018-02-05       PELA MANHÃ      02/05/2018
# 1777854  02/05/2018 17:24:45     2018-02-05       PELA MANHÃ      02/05/2018
#
#               DATAELABORACAO    BO_AUTORIA  ... IDADE PLACA_VEICULO  \
# 1696362  01/01/2018 04:10:03  Desconhecida  ...   NaN       FAG1865
# 1777862  02/05/2018 17:28:51  Desconhecida  ...   NaN       FDQ7766
# 1777857  02/05/2018 17:36:20  Desconhecida  ...   NaN       CDI3914
# 1777855  02/05/2018 17:25:57  Desconhecida  ...   NaN           NaN
# 1777854  02/05/2018 17:24:45  Desconhecida  ...   NaN       EMS7306
#
#         UF_VEICULO  CIDADE_VEICULO DESCR_COR_VEICULO  \
# 1696362         SP         S.PAULO             Preta
# 1777862         SP         S.PAULO             Cinza
# 1777857         SP         S.PAULO              Azul
# 1777855        NaN             NaN               NaN
# 1777854         SP         S.PAULO             Preta
#
#               DESCR_MARCA_VEICULO ANO_FABRICACAO ANO_MODELO  \
# 1696362      I/FIAT SIENA EL FLEX         2011.0     2011.0
# 1777862        HONDA/HR-V EXL CVT         2016.0     2016.0
# 1777857     HONDA/CG 150 TITAN KS         2008.0     2008.0
# 1777855                       NaN            NaN        NaN
# 1777854  I/KIA SPORTAGE EX2 2.0G2         2010.0     2010.0
#
#         DESCR_TIPO_VEICULO DIASEMANA
# 1696362          AUTOMOVEL         0
# 1777862          AUTOMOVEL         0
# 1777857          MOTOCICLO         0
# 1777855                NaN         0
# 1777854          AUTOMOVEL         0
#
# [5 rows x 39 columns]

# %%
furtos_2018.to_csv('D:\\EPS\\TCC\\data_cleaned\\SSP\\furtos2018.csv', sep=",", index=False)

# %% [markdown]
# ## Criação da base de 2018 para roubos

# %%
# Criação da base de 2018 para roubos
df_roubos = pd.read_csv('D:\\EPS\\TCC\\data_cleaned\\SSP\\roubosConcat.csv', sep=",", decimal=".")

# %%
df_roubos.columns
# Out:
# Index(['ANO_BO', 'NUM_BO', 'NUMERO_BOLETIM', 'BO_INICIADO', 'BO_EMITIDO',
#        'DATAOCORRENCIA', 'PERIDOOCORRENCIA', 'DATACOMUNICACAO',
#        'DATAELABORACAO', 'BO_AUTORIA', 'FLAGRANTE', 'NUMERO_BOLETIM_PRINCIPAL',
#        'LOGRADOURO', 'NUMERO', 'BAIRRO', 'CIDADE', 'UF', 'LATITUDE',
#        'LONGITUDE', 'DESCRICAOLOCAL', 'EXAME', 'SOLUCAO', 'DELEGACIA_NOME',
#        'DELEGACIA_CIRCUNSCRICAO', 'ESPECIE', 'RUBRICA', 'DESDOBRAMENTO',
#        'STATUS', 'SEXO', 'IDADE', 'PLACA_VEICULO', 'UF_VEICULO',
#        'CIDADE_VEICULO', 'DESCR_COR_VEICULO', 'DESCR_MARCA_VEICULO',
#        'ANO_FABRICACAO', 'ANO_MODELO', 'DESCR_TIPO_VEICULO'],
#       dtype='object')

# %%
df_roubos.head()
# Out:
#    ANO_BO  NUM_BO NUMERO_BOLETIM          BO_INICIADO           BO_EMITIDO  \
# 0    2003       1         1/2003  01/01/2003 05:19:33  01/01/2003 05:23:16
# 1    2003      15        15/2003  01/01/2003 09:00:57  01/01/2003 09:01:20
# 2    2003      15        15/2003  01/01/2003 09:00:57  01/01/2003 09:01:20
# 3    2003       8         8/2003  02/01/2003 01:35:36  02/01/2003 01:36:31
# 4    2003      16        16/2003  02/01/2003 12:45:29  02/01/2003 13:02:29
#
#   DATAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO       DATAELABORACAO  \
# 0     01/01/2003     DE MADRUGADA      01/01/2003  01/01/2003 05:19:33
# 1     01/01/2003     DE MADRUGADA      01/01/2003  01/01/2003 09:00:57
# 2     01/01/2003     DE MADRUGADA      01/01/2003  01/01/2003 09:00:57
# 3     02/01/2003     DE MADRUGADA      02/01/2003  02/01/2003 01:35:36
# 4     31/12/2002          A TARDE      02/01/2003  02/01/2003 12:45:29
#
#      BO_AUTORIA  ... SEXO IDADE PLACA_VEICULO  UF_VEICULO CIDADE_VEICULO  \
# 0  Desconhecida  ...  NaN   NaN           NaN         NaN            NaN
# 1  Desconhecida  ...  NaN   NaN           NaN         NaN            NaN
# 2  Desconhecida  ...  NaN   NaN           NaN         NaN            NaN
# 3  Desconhecida  ...  NaN   NaN           NaN         NaN            NaN
# 4  Desconhecida  ...  NaN   NaN           NaN         NaN            NaN
#
#   DESCR_COR_VEICULO DESCR_MARCA_VEICULO ANO_FABRICACAO ANO_MODELO  \
# 0               NaN                 NaN            NaN        NaN
# 1               NaN                 NaN            0.0        0.0
# 2               NaN                 NaN            0.0        0.0
# 3               NaN                 NaN            NaN        NaN
# 4               NaN                 NaN            NaN        NaN
#
#   DESCR_TIPO_VEICULO
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 38 columns]

# %%
# Convertemos para datetime
df_roubos['DATAOCORRENCIA'] = pd.to_datetime(df_roubos['DATAOCORRENCIA'], errors = 'coerce')

# %%
df_roubos.head()
# Out:
#    ANO_BO  NUM_BO NUMERO_BOLETIM          BO_INICIADO           BO_EMITIDO  \
# 0    2003       1         1/2003  01/01/2003 05:19:33  01/01/2003 05:23:16
# 1    2003      15        15/2003  01/01/2003 09:00:57  01/01/2003 09:01:20
# 2    2003      15        15/2003  01/01/2003 09:00:57  01/01/2003 09:01:20
# 3    2003       8         8/2003  02/01/2003 01:35:36  02/01/2003 01:36:31
# 4    2003      16        16/2003  02/01/2003 12:45:29  02/01/2003 13:02:29
#
#   DATAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO       DATAELABORACAO  \
# 0     2003-01-01     DE MADRUGADA      01/01/2003  01/01/2003 05:19:33
# 1     2003-01-01     DE MADRUGADA      01/01/2003  01/01/2003 09:00:57
# 2     2003-01-01     DE MADRUGADA      01/01/2003  01/01/2003 09:00:57
# 3     2003-02-01     DE MADRUGADA      02/01/2003  02/01/2003 01:35:36
# 4     2002-12-31          A TARDE      02/01/2003  02/01/2003 12:45:29
#
#      BO_AUTORIA  ... SEXO IDADE PLACA_VEICULO  UF_VEICULO CIDADE_VEICULO  \
# 0  Desconhecida  ...  NaN   NaN           NaN         NaN            NaN
# 1  Desconhecida  ...  NaN   NaN           NaN         NaN            NaN
# 2  Desconhecida  ...  NaN   NaN           NaN         NaN            NaN
# 3  Desconhecida  ...  NaN   NaN           NaN         NaN            NaN
# 4  Desconhecida  ...  NaN   NaN           NaN         NaN            NaN
#
#   DESCR_COR_VEICULO DESCR_MARCA_VEICULO ANO_FABRICACAO ANO_MODELO  \
# 0               NaN                 NaN            NaN        NaN
# 1               NaN                 NaN            0.0        0.0
# 2               NaN                 NaN            0.0        0.0
# 3               NaN                 NaN            NaN        NaN
# 4               NaN                 NaN            NaN        NaN
#
#   DESCR_TIPO_VEICULO
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#
# [5 rows x 38 columns]

# %%
roubos_2018 = df_roubos[df_roubos['DATAOCORRENCIA'].dt.year == 2018]

# %%
roubos_2018.head()
# Out:
#          ANO_BO  NUM_BO NUMERO_BOLETIM          BO_INICIADO  \
# 2024721    2017   12386     12386/2017  01/01/2018 00:42:53
# 2024725    2018       1         1/2018  01/01/2018 01:12:07
# 2024727    2018       1         1/2018  01/01/2018 01:37:25
# 2024728    2018       1         1/2018  01/01/2018 01:53:28
# 2024731    2018      70        70/2018  01/01/2018 02:40:15
#
#                   BO_EMITIDO DATAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO  \
# 2024721  01/01/2018 01:00:26     2018-01-01     DE MADRUGADA      01/01/2018
# 2024725  01/01/2018 01:56:02     2018-01-01     DE MADRUGADA      01/01/2018
# 2024727  01/01/2018 02:05:39     2018-01-01     DE MADRUGADA      01/01/2018
# 2024728  01/01/2018 02:13:04     2018-01-01     DE MADRUGADA      01/01/2018
# 2024731  01/01/2018 02:40:15     2018-01-01     DE MADRUGADA      01/01/2018
#
#               DATAELABORACAO    BO_AUTORIA  ... SEXO IDADE PLACA_VEICULO  \
# 2024721  01/01/2018 00:42:53  Desconhecida  ...  NaN   NaN       EHI4080
# 2024725  01/01/2018 01:12:07  Desconhecida  ...  NaN   NaN       BAA6627
# 2024727  01/01/2018 01:37:25  Desconhecida  ...  NaN   NaN       PYS5262
# 2024728  01/01/2018 01:53:28  Desconhecida  ...  NaN   NaN       FHT0878
# 2024731  01/01/2018 02:40:15  Desconhecida  ...  NaN   NaN       EPC9090
#
#          UF_VEICULO  CIDADE_VEICULO DESCR_COR_VEICULO  \
# 2024721          SP       RIO CLARO             Preta
# 2024725          SP         S.PAULO             Preta
# 2024727          MG  BELO HORIZONTE              Azul
# 2024728          SP         S.PAULO          Vermelho
# 2024731          SP         S.PAULO             Prata
#
#               DESCR_MARCA_VEICULO ANO_FABRICACAO ANO_MODELO DESCR_TIPO_VEICULO
# 2024721     HONDA/CBX 250 TWISTER         2008.0     2008.0          MOTOCICLO
# 2024725   RENAULT/SANDERO EXPR 10         2015.0     2016.0          AUTOMOVEL
# 2024727  HYUNDAI/HB20 1.0M COMFOR         2016.0     2017.0          AUTOMOVEL
# 2024728            VW/FOX 1.0 GII         2013.0     2013.0          AUTOMOVEL
# 2024731        HONDA/CITY LX FLEX         2010.0     2010.0          AUTOMOVEL
#
# [5 rows x 38 columns]

# %%
roubos_2018['CIDADE'] = roubos_2018['CIDADE'].str.upper()
# Out:
# D:\Programas\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# Dropamos outras cidades que nao são SP
roubos_2018.drop(roubos_2018[(roubos_2018.CIDADE != 'S.PAULO') & (roubos_2018.CIDADE != 'SAO PAULO') & (roubos_2018.CIDADE != 'SÃO PAULO') & (roubos_2018.CIDADE != 'SP')].index, inplace=True)

# %%
roubos_2018['CIDADE'].unique()
# Out:
# array(['S.PAULO'], dtype=object)

# %%
roubos_2018['DIASEMANA'] = roubos_2018['DATAOCORRENCIA'].dt.dayofweek
# Out:
# D:\Programas\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
roubos_2018.sort_values('DIASEMANA', inplace=True)
# Out:
# D:\Programas\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
roubos_2018['DIASEMANA'].unique()
# Out:
# array([0, 1, 2, 3, 4, 5, 6], dtype=int64)

# %%
roubos_2018.head()
# Out:
#          ANO_BO   NUM_BO NUMERO_BOLETIM          BO_INICIADO  \
# 2024725    2018        1         1/2018  01/01/2018 01:12:07
# 2107983    2018      897       897/2018  24/04/2018 16:49:57
# 2107982    2018      897       897/2018  24/04/2018 16:49:57
# 2045102    2018  1354556   1354556/2018  23/10/2018 09:36:53
# 2045103    2018  1354556   1354556/2018  23/10/2018 09:36:53
#
#                   BO_EMITIDO DATAOCORRENCIA PERIDOOCORRENCIA DATACOMUNICACAO  \
# 2024725  01/01/2018 01:56:02     2018-01-01     DE MADRUGADA      01/01/2018
# 2107983  24/04/2018 17:31:45     2018-04-23          A NOITE      24/04/2018
# 2107982  24/04/2018 17:31:45     2018-04-23          A NOITE      24/04/2018
# 2045102  23/10/2018 09:36:32     2018-10-22          A NOITE      22/10/2018
# 2045103  23/10/2018 09:36:32     2018-10-22          A NOITE      22/10/2018
#
#               DATAELABORACAO    BO_AUTORIA  ... IDADE PLACA_VEICULO  \
# 2024725  01/01/2018 01:12:07  Desconhecida  ...   NaN       BAA6627
# 2107983  24/04/2018 16:49:57      Ignorado  ...   NaN       CNR8559
# 2107982  24/04/2018 16:49:57      Ignorado  ...   NaN           NaN
# 2045102  23/10/2018 09:36:53  Desconhecida  ...   NaN           NaN
# 2045103  23/10/2018 09:36:53  Desconhecida  ...   NaN       FNX4001
#
#         UF_VEICULO  CIDADE_VEICULO DESCR_COR_VEICULO      DESCR_MARCA_VEICULO  \
# 2024725         SP         S.PAULO             Preta  RENAULT/SANDERO EXPR 10
# 2107983         SP       RIO CLARO             Cinza       REB/NOMA SR3E27 CS
# 2107982        NaN             NaN               NaN                      NaN
# 2045102         SP       SÃO PAULO             Preta              H/HONDA 150
# 2045103         SP       SÃO PAULO            Branco              YAMAHA/NMAX
#
#         ANO_FABRICACAO ANO_MODELO DESCR_TIPO_VEICULO DIASEMANA
# 2024725         2015.0     2016.0          AUTOMOVEL         0
# 2107983         2013.0     2013.0       SEMI-REBOQUE         0
# 2107982            0.0        0.0                NaN         0
# 2045102            NaN        NaN          MOTOCICLO         0
# 2045103         2016.0        NaN          MOTOCICLO         0
#
# [5 rows x 39 columns]

# %%
roubos_2018.to_csv('D:\\EPS\\TCC\\data_cleaned\\SSP\\roubos_2018.csv', sep=",", index=False)
